# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

pil=Image.open('thor.jfif')

# %%
#pil=Image.open('thor.jfif')
arr=np.array(pil)
arr.shape
# Out:
# (194, 259, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=259x194 at 0x2553A4AF0D0>

# %%
cut=arr[:5,:5]

# %%
plt.imshow(cut)

# %%
work=arr.copy()

# %%
work[:, :, [1,2]]=0
plt.imshow(work)

# %%
gray=arr.mean(axis=2)
plt.imshow(gray,cmap='gray')
